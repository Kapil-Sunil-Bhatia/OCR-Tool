# %%
import numpy as np
import pandas as pd
import cv2
import pytesseract
from glob import glob
import spacy
import re
import string

# %%
def cleanText(txt):
    whitespace = string.whitespace
    punctuation = "!#$%&\'()*+:;<=>?[\\]^`{|}~"
    tableWhitespace = str.maketrans('','',whitespace)
    tablePunctuation = str.maketrans('','',punctuation)
    text = str(txt)
    text = text.lower()
    removewhitespace = text.translate(tableWhitespace)
    removepunctuation = removewhitespace.translate(tablePunctuation)
    
    return str(removepunctuation)

# %%
### Load NER model
model_ner = spacy.load('./output/model-best/')

# %%
# Load Image
image = cv2.imread('./data/0115.jpeg')

# cv2.imshow('businesscard',image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# extract data using Pytesseract 
tessData = pytesseract.image_to_data(image)
# convert into dataframe
tessList = list(map(lambda x:x.split('\t'), tessData.split('\n')))
df = pd.DataFrame(tessList[1:],columns=tessList[0])
df.dropna(inplace=True) # drop missing values
df['text'] = df['text'].apply(cleanText)

# convet data into content
df_clean = df.query('text != "" ')
content = " ".join([w for w in df_clean['text']])
print(content)
# get prediction from NER model
doc = model_ner(content)
# Out:
# me ors somaiya t the institution of s vidyavihar engineering and technology ‘j om s “ye is k j somaiya institute of technology participation certificate of yash chauhan has participated in national level poster cum project competition “kjsit-iet-intech 2k23” organized by k j somaiya institute of technology, sion, mumbai in association with the institution of engineering and technology, mumbai local network on march 25, 2023 vikeaut sankhe qp pee mr. vikrant sankhe dr. sunita patil dr. suresh ukarande chairman, iet mumbai ln vice principal, kjsieit principal, kjsieit

# %%
from spacy import displacy

# %%
displacy.serve(doc,style='ent')
auto_select_port=True
# Out:
# D:\kapil somaiya study sem 5 offline\minor-project\docuscan\Lib\site-packages\spacy\displacy\__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">me
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     somaiya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#  t
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     institution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vidyavihar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     and
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#  ‘j om s “ye
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     is
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     k
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     j
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     somaiya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     institute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     participation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-TYP</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     certificate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-TYP</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-STU</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chauhan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-STU</span>
# </mark>
#  has
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     participated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     national
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     level
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="backg
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
displacy.render(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">me
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     somaiya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#  t
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     institution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vidyavihar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     and
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#  ‘j om s “ye
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     is
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     k
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     j
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     somaiya
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     institute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     technology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-COI</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     participation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-TYP</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     certificate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-TYP</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yash
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-STU</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chauhan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-STU</span>
# </mark>
#  has
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     participated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     national
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     level
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     poster
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0

# %%
docjson = doc.to_json()
docjson.keys()
# Out:
# dict_keys(['text', 'ents', 'tokens'])

# %%
docjson['text']
# Out:
# 'me ors somaiya t the institution of s vidyavihar engineering and technology ‘j om s “ye is k j somaiya institute of technology participation certificate of yash chauhan has participated in national level poster cum project competition “kjsit-iet-intech 2k23” organized by k j somaiya institute of technology, sion, mumbai in association with the institution of engineering and technology, mumbai local network on march 25, 2023 vikeaut sankhe qp pee mr. vikrant sankhe dr. sunita patil dr. suresh ukarande chairman, iet mumbai ln vice principal, kjsieit principal, kjsieit'

# %%
docjson['tokens']
# Out:
# [{'id': 0, 'start': 0, 'end': 2},
#  {'id': 1, 'start': 3, 'end': 6},
#  {'id': 2, 'start': 7, 'end': 14},
#  {'id': 3, 'start': 15, 'end': 16},
#  {'id': 4, 'start': 17, 'end': 20},
#  {'id': 5, 'start': 21, 'end': 32},
#  {'id': 6, 'start': 33, 'end': 35},
#  {'id': 7, 'start': 36, 'end': 37},
#  {'id': 8, 'start': 38, 'end': 48},
#  {'id': 9, 'start': 49, 'end': 60},
#  {'id': 10, 'start': 61, 'end': 64},
#  {'id': 11, 'start': 65, 'end': 75},
#  {'id': 12, 'start': 76, 'end': 77},
#  {'id': 13, 'start': 77, 'end': 78},
#  {'id': 14, 'start': 79, 'end': 81},
#  {'id': 15, 'start': 82, 'end': 83},
#  {'id': 16, 'start': 84, 'end': 85},
#  {'id': 17, 'start': 85, 'end': 87},
#  {'id': 18, 'start': 88, 'end': 90},
#  {'id': 19, 'start': 91, 'end': 92},
#  {'id': 20, 'start': 93, 'end': 94},
#  {'id': 21, 'start': 95, 'end': 102},
#  {'id': 22, 'start': 103, 'end': 112},
#  {'id': 23, 'start': 113, 'end': 115},
#  {'id': 24, 'start': 116, 'end': 126},
#  {'id': 25, 'start': 127, 'end': 140},
#  {'id': 26, 'start': 141, 'end': 152},
#  {'id': 27, 'start': 153, 'end': 155},
#  {'id': 28, 'start': 156, 'end': 160},
#  {'id': 29, 'start': 161, 'end': 168},
#  {'id': 30, 'start': 169, 'end': 172},
#  {'id': 31, 'start': 173, 'end': 185},
#  {'id': 32, 'start': 186, 'end': 188},
#  {'id': 33, 'start': 189, 'end': 197},
#  {'id': 34, 'start': 198, 'end': 203},
#  {'id': 35, 'start': 204, 'end': 210},
#  {'id': 36, 'start': 211, 'end': 214},
#  {'id': 37, 'start': 215, 'end': 222},
#  {'id': 38, 'start': 223, 'end': 234},
#  {'id': 39, 'start': 235, 'end': 236},
#  {'id': 40, 'start': 236, 'end': 241},
#  {'id': 41, 'start': 241, 'end': 242},
#  {'id': 42, 'start': 242, 'end': 245},
#  {'id': 43, 'start': 245, 'end': 246},
#  {'id': 44, 'start': 246, 'end': 252},
#  {'id': 45, 'start': 253, 'end': 257},
#  {'id': 46, 'start': 257, 'end': 258},
#  {'id': 47, 'start': 259, 'end': 268},
#  {'id': 48, 'start': 269, 'end': 271},
#  {'id': 49, 'start': 272, 'end': 273},
#  {'id': 50, 'start': 274, 'end': 275},
#  {'id': 51, 'start': 276, 'end': 283},
#  {'id': 52, 'start': 284, 'end': 293},
#  {'id': 53, 'start': 294, 'end': 296},
#  {'id': 54, 'start': 297, 'end': 307},
#  {'id': 55, 'start': 307, 'end': 308},
#  {'id': 56, 'start': 309, 'end': 313},
#  {'id': 57, 'start': 313, 'end': 314},
#  {'id': 58, 'start': 315, 'end': 321},
#  {'id': 59, 'start': 322, 'end': 324},
#  {'id': 60, 'start': 325, 'end': 336},
#  {'id': 61, 'start': 337, 'end': 341},
#  {'id': 62, 'start': 342, 'end': 345},
#  {'id': 63, 'start': 346, 'end': 357},
#  {'id': 64, 'start': 358, 'end': 360},
#  {'id': 65, 'start': 361, 'end': 372},
#  {'id': 66, 'start': 373, 'end': 376},
#  {'id': 67, 'start': 377, 'end': 387},
#  {'id': 68, 'start': 387, 'end': 388},
#  {'id': 69, 'start': 389, 'end': 395},
#  {'id': 70, 'start': 396, 'end': 401},
#  {'id': 71, 'start': 402, 'end': 409},
#  {'id': 72, 'start': 410, 'end': 412},
#  {'id': 73, 'start': 413, 'end': 418},
#  {'id': 74, 'start': 419, 'end': 421},
#  {'id': 75, 'start': 421, 'end': 422},
#  {'id': 76, 'start': 423, 'end': 427},
#  {'id': 77, 'start': 428, 'end': 435},
#  {'id': 78, 'start': 436, 'end': 442},
#  {'id': 79, 'start': 443, 'end': 445},
#  {'id': 80, 'start': 446, 'end': 449},
#  {'id': 81, 'start': 450, 'end': 452},
#  {'id': 82, 'start': 452, 'end': 453},
#  {'id': 83, 'start': 454, 'end': 461},
#  {'id': 84, 'start': 462, 'end': 468},
#  {'id': 85, 'start': 469, 'end': 471},
#  {'id': 86, 'start': 471, 'end': 472},
#  {'id': 87, 'start': 473, 'end': 479},
#  {'id': 88, 'start': 480, 'end': 485},
#  {'id': 89, 'start': 486, 'end': 488},
#  {'id': 90, 'start': 488, 'end': 489},
#  {'id': 91, 'start': 490, 'end': 496},
#  {'id': 92, 'start': 497, 'end': 505},
#  {'id': 93, 'start': 506, 'end': 514},
#  {'id': 94, 'start': 514, 'end': 515},
#  {'id': 95, 'start': 516, 'end': 519},
#  {'id': 96, 'start': 520, 'end': 526},
#  {'id': 97, 'start': 527, 'end': 529},
#  {'id': 98, 'start': 530, 'end': 534},
#  {'id': 99, 'start': 535, 'end': 544},
#  {'id': 100, 'start': 544, 'end': 545},
#  {'id': 101, 'start': 546, 'end': 553},
#  {'id': 102, 'start': 554, 'end': 563},
#  {'id': 103, 'start': 563, 'end': 564},
#  {'id': 104, 'start': 565, 'end': 572}]

# %%
docjson['ents']
# Out:
# [{'start': 3, 'end': 6, 'label': 'I-DES'},
#  {'start': 7, 'end': 14, 'label': 'I-COI'},
#  {'start': 17, 'end': 20, 'label': 'B-COI'},
#  {'start': 21, 'end': 32, 'label': 'I-COI'},
#  {'start': 33, 'end': 35, 'label': 'I-COI'},
#  {'start': 36, 'end': 37, 'label': 'I-COI'},
#  {'start': 38, 'end': 48, 'label': 'I-COI'},
#  {'start': 49, 'end': 60, 'label': 'I-COI'},
#  {'start': 61, 'end': 64, 'label': 'I-COI'},
#  {'start': 65, 'end': 75, 'label': 'I-COI'},
#  {'start': 88, 'end': 90, 'label': 'I-COI'},
#  {'start': 91, 'end': 92, 'label': 'I-COI'},
#  {'start': 93, 'end': 94, 'label': 'I-COI'},
#  {'start': 95, 'end': 102, 'label': 'I-COI'},
#  {'start': 103, 'end': 112, 'label': 'I-COI'},
#  {'start': 113, 'end': 115, 'label': 'I-COI'},
#  {'start': 116, 'end': 126, 'label': 'I-COI'},
#  {'start': 127, 'end': 140, 'label': 'B-TYP'},
#  {'start': 141, 'end': 152, 'label': 'I-TYP'},
#  {'start': 156, 'end': 160, 'label': 'B-STU'},
#  {'start': 161, 'end': 168, 'label': 'I-STU'},
#  {'start': 173, 'end': 185, 'label': 'B-DES'},
#  {'start': 186, 'end': 188, 'label': 'I-DES'},
#  {'start': 189, 'end': 197, 'label': 'I-DES'},
#  {'start': 198, 'end': 203, 'label': 'I-DES'},
#  {'start': 204, 'end': 210, 'label': 'I-DES'},
#  {'start': 211, 'end': 214, 'label': 'I-DES'},
#  {'start': 215, 'end': 222, 'label': 'I-DES'},
#  {'start': 223, 'end': 234, 'label': 'I-DES'},
#  {'start': 235, 'end': 252, 'label': 'I-DES'},
#  {'start': 253, 'end': 258, 'label': 'I-DES'},
#  {'start': 259, 'end': 268, 'label': 'I-DES'},
#  {'start': 269, 'end': 271, 'label': 'I-DES'},
#  {'start': 272, 'end': 273, 'label': 'I-DES'},
#  {'start': 274, 'end': 275, 'label': 'I-DES'},
#  {'start': 276, 'end': 283, 'label': 'I-DES'},
#  {'start': 284, 'end': 293, 'label': 'I-COI'},
#  {'start': 294, 'end': 296, 'label': 'I-COI'},
#  {'start': 297, 'end': 307, 'label': 'I-COI'},
#  {'start': 322, 'end': 324, 'label': 'I-DES'},
#  {'start': 325, 'end': 336, 'label': 'I-DES'},
#  {'start': 337, 'end': 341, 'label': 'I-DES'},
#  {'start': 342, 'end': 345, 'label': 'I-DES'},
#  {'start': 346, 'end': 357, 'label': 'I-COI'},
#  {'start': 358, 'end': 360, 'label': 'I-COI'},
#  {'start': 361, 'end': 372, 'label': 'I-COI'},
#  {'start': 373, 'end': 376, 'label': 'I-COI'},
#  {'start': 377, 'end': 387, 'label': 'I-COI'},
#  {'start': 396, 'end': 401, 'label': 'I-DES'},
#  {'start': 402, 'end': 409, 'label': 'I-DES'},
#  {'start': 410, 'end': 412, 'label': 'B-DAT'},
#  {'start': 413, 'end': 418, 'label': 'I-DAT'},
#  {'start': 419, 'end': 421, 'label': 'I-DAT'},
#  {'start': 428, 'end': 435, 'label': 'B-NCER'},
#  {'start': 436, 'end': 442, 'label': 'I-NCER'},
#  {'start': 450, 'end': 453, 'label': 'B-NCER'},
#  {'start': 454, 'end': 461, 'label': 'I-NCER'},
#  {'start': 462, 'end': 468, 'label': 'I-NCER'},
#  {'start': 469, 'end': 472, 'label': 'B-NCER'},
#  {'start': 473, 'end': 479, 'label': 'I-NCER'},
#  {'start': 480, 'end': 485, 'label': 'I-NCER'},
#  {'start': 486, 'end': 489, 'label': 'B-NCER'},
#  {'start': 490, 'end': 496, 'label': 'I-NCER'},
#  {'start': 497, 'end': 505, 'label': 'I-NCER'}]

# %%
doc_text = docjson['text']

# %%
datafram_tokens = pd.DataFrame(docjson['tokens'])
datafram_tokens['token'] = datafram_tokens[['start','end']].apply(
        lambda x:doc_text[x[0]:x[1]] , axis = 1)

datafram_tokens.head(10)
# Out:
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\3380815399.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda x:doc_text[x[0]:x[1]] , axis = 1)
#    id  start  end        token
# 0   0      0    2           me
# 1   1      3    6          ors
# 2   2      7   14      somaiya
# 3   3     15   16            t
# 4   4     17   20          the
# 5   5     21   32  institution
# 6   6     33   35           of
# 7   7     36   37            s
# 8   8     38   48   vidyavihar
# 9   9     49   60  engineering

# %%
doc_text[49:60]
# Out:
# 'engineering'

# %%
right_table = pd.DataFrame(docjson['ents'])[['start','label']]
datafram_tokens = pd.merge(datafram_tokens,right_table,how='left',on='start')

# %%
datafram_tokens.fillna('O',inplace=True)
datafram_tokens.head(10)
# Out:
#    id  start  end        token  label
# 0   0      0    2           me      O
# 1   1      3    6          ors  I-DES
# 2   2      7   14      somaiya  I-COI
# 3   3     15   16            t      O
# 4   4     17   20          the  B-COI
# 5   5     21   32  institution  I-COI
# 6   6     33   35           of  I-COI
# 7   7     36   37            s  I-COI
# 8   8     38   48   vidyavihar  I-COI
# 9   9     49   60  engineering  I-COI

# %%
#join label to df_clean 'dataframe'
df_clean['end'] = df_clean['text'].apply(lambda x: len(x)+1).cumsum() - 1
df_clean['start'] = df_clean[['text','end']].apply(lambda x: x[1] - len(x[0]),axis=1)
# Out:
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\146087620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['end'] = df_clean['text'].apply(lambda x: len(x)+1).cumsum() - 1
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\146087620.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_clean['start'] = df_clean[['text','end']].apply(lambda x: x[1] - len(x[0]),axis=1)
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\146087620.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['start'] = df_clean[['text','end']].apply(lambda x: x[1] - len(x[0]),axis=1)

# %%
#inner join with start
dataframe_info = pd.merge(df_clean,datafram_tokens[['start','token','label']],how='inner',on='start')

# %%
dataframe_info.head()
# Out:
#   level page_num block_num par_num line_num word_num  left top width height  \
# 0     5        1         1       1        1        1    52  82    10      8
# 1     5        1         2       1        1        1    66  43    82     56
# 2     5        1         2       1        1        2   199  44   309     67
# 3     5        1         2       1        1        5  1116  46    69     92
# 4     5        1         2       1        1        6  1194  80    50     25
#
#   conf     text  end  start    token  label
# 0   27       me    2      0       me      O
# 1   47      ors    6      3      ors  I-DES
# 2   65  somaiya   14      7  somaiya  I-COI
# 3   88        t   16     15        t      O
# 4   96      the   20     17      the  B-COI

# %%
dataframe_info.tail(10)
# Out:
#    level page_num block_num par_num line_num word_num  left   top width  \
# 77     5        1        12       1        3        9  1340  1082   145
# 78     5        1        13       1        1        1   125  1149   154
# 79     5        1        13       1        1        2   291  1150    56
# 80     5        1        13       1        1        3   357  1149   127
# 81     5        1        13       1        1        4   493  1150    50
# 82     5        1        13       1        1        5   640  1149    68
# 83     5        1        13       1        1        6   718  1149   143
# 84     5        1        13       1        1        7   872  1150   133
# 85     5        1        13       1        1        8  1187  1149   144
# 86     5        1        13       1        1        9  1351  1150   132
#
#    height conf        text  end  start      token   label
# 77     27   92    ukarande  505    497   ukarande  I-NCER
# 78     33   93   chairman,  515    506   chairman       O
# 79     26   92         iet  519    516        iet       O
# 80     27   96      mumbai  526    520     mumbai       O
# 81     26   96          ln  529    527         ln       O
# 82     27   96        vice  534    530       vice       O
# 83     35   93  principal,  545    535  principal       O
# 84     26   56     kjsieit  553    546    kjsieit       O
# 85     35   93  principal,  564    554  principal       O
# 86     26   41     kjsieit  572    565    kjsieit       O

# %% [markdown]
# ## Bounding Box

# %%
bb_df = dataframe_info.query("label != 'O' ")
img = image.copy()

for x,y,w,h,label in bb_df[['left','top','width','height','label']].values:
    x = int(x)
    y = int(y)
    w = int(w)
    h = int(h)
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    cv2.putText(img,str(label),(x,y),cv2.FONT_HERSHEY_PLAIN,1,(255,0,255),2)

cv2.imshow('Predictions',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
bb_df.head()
# Out:
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\2854881843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['label'] = bb_df['label'].apply(lambda x: x[2:])
#   level page_num block_num par_num line_num word_num  left top width height  \
# 1     5        1         2       1        1        1    66  43    82     56
# 2     5        1         2       1        1        2   199  44   309     67
# 4     5        1         2       1        1        6  1194  80    50     25
# 5     5        1         2       1        1        7  1258  82   140     23
# 6     5        1         2       1        1        8  1410  80    30     25
#
#   conf         text  end  start        token label
# 1   47          ors    6      3          ors   DES
# 2   65      somaiya   14      7      somaiya   COI
# 4   96          the   20     17          the   COI
# 5   96  institution   32     21  institution   COI
# 6   96           of   35     33           of   COI

# %%
#group the labels
class groupgen():
    def __init__(self):
        self.id = 0
        self.text = ''
        
    def getgroup(self,text):
        if self.text == text:
            return self.id
        else:
            self.id +=1
            self.text = text
            return self.id
grp_gen =  groupgen()

# %%
bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)
# Out:
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\472836701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['group'] = bb_df['label'].apply(grp_gen.getgroup)

# %%
#right and bottom of bounding box
bb_df[['left','top','width','height']] = bb_df[['left','top','width','height']].astype(int)
bb_df['right'] = bb_df['left'] + bb_df['width'] 
bb_df['bottom'] = bb_df['top'] + bb_df['height']
# Out:
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\3027534292.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df[['left','top','width','height']] = bb_df[['left','top','width','height']].astype(int)
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\3027534292.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['right'] = bb_df['left'] + bb_df['width']
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\3027534292.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb_df['bottom'] = bb_df['top'] + bb_df['height']

# %%
# tagging: grouby group
col_group = ['left','top','right','bottom','label','token','group']
group_tag_img = bb_df[col_group].groupby(by='group')

# %%
img_tagging = group_tag_img.agg({
    'left':min,
    'right':max,
    'top' :min,
    'bottom' :max,
    'label' :np.unique,
    'token' : lambda x:" ".join(x)
})
# Out:
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\1112388624.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'min' instead.
#   img_tagging = group_tag_img.agg({
# C:\Users\kapil\AppData\Local\Temp\ipykernel_10096\1112388624.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'max' instead.
#   img_tagging = group_tag_img.agg({

# %%
img_tagging
# Out:
#        left  right  top  bottom   label  \
# group
# 1        66    148   43      99   [DES]
# 2       111   1594   44     179   [COI]
# 3       442   1182  220     282   [TYP]
# 4       654    965  336     371   [STU]
# 5       137   1458  443     706   [DES]
# 6       579    992  668     706   [COI]
# 7       167    955  743     848   [DES]
# 8       247   1002  818     856   [COI]
# 9      1178   1443  819     848   [DES]
# 10      641    873  894     929   [DAT]
# 11      196   1485  975    1109  [NCER]
#
#                                                    token
# group
# 1                                                    ors
# 2      somaiya the institution of s vidyavihar engine...
# 3                              participation certificate
# 4                                           yash chauhan
# 5      participated in national level poster cum proj...
# 6                                institute of technology
# 7                                in association with the
# 8              institution of engineering and technology
# 9                                          local network
# 10                                           on march 25
# 11     vikeaut sankhe mr vikrant sankhe dr sunita pat...

# %%
img_bb = image.copy()
for l, r, t, b, label, token in img_tagging.values:
    cv2.rectangle(img_bb, (l, t), (r, b), (0, 255, 0), 2)

    # Convert label to string
    label = str(label)

    cv2.putText(img_bb, label, (l, t), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 255),2)

cv2.imshow('Bounding Box BusinessCard', img_bb)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Parser

# %%
import re
def parser (text,label):
    if label == 'DAT':
        text = text.lower()
        allow_special_char = '_./\-'
        text = re.sub(r'^0-9{}\D ]'.format(allow_special_char),'',text)
    elif label == 'NCER':
        text = text.lower()
        allow_special_char = '_.\-'
        text = re.sub(r'[^A-Za-z0-9{} ]'.format(allow_special_char),'',text)
    elif label in ('STU', 'TYP', 'DES','COI'):
        text = text.lower()
        text = re.sub(r'[^a-z]','',text)
        text = text.title()
    return text

# %%
parser('Srikanth 1896196','STU')
# Out:
# 'Srikanth'

# %%
parser('23/02/2023','DAT')
# Out:
# '23/02/2023%$&))'

# %%
info_array = dataframe_info[['token','label']].values
entities = dict(STU=[],DES=[],COI=[],DAT=[],NCER=[],TYP=[])
previous = 'O'

for token,label in info_array:
    #print(token,label)
    bio_tag = label[:1]
    label_tag = label[2:]
    
    #step 1 parse the token
    text = parser(token,label_tag)
    if bio_tag in ('B','I'):
        if previous != label_tag:
            entities[label_tag].append(text)
        else:
            if bio_tag == "B":
                entities[label_tag].append(text)
            else:
                if label_tag in ("STU",'COI','DES'):
                    entities[label_tag][-1] = entities[label_tag][-1] + " " + text
                else:
                    entities[label_tag][-1] = entities[label_tag][-1] + text
    previous = label_tag

# %%
entities
# Out:
# {'STU': ['Yash Chauhan'],
#  'DES': ['Ors',
#   'Participated In National Level Poster Cum Project Competition  K Organized By K J Somaiya',
#   'In Association With The',
#   'Local Network'],
#  'COI': ['Somaiya',
#   'The Institution Of S Vidyavihar Engineering And Technology',
#   'Is K J Somaiya Institute Of Technology',
#   'Institute Of Technology',
#   'Institution Of Engineering And Technology'],
#  'DAT': ['onmarch25'],
#  'NCER': ['vikeautsankhe',
#   'mrvikrantsankhe',
#   'drsunitapatil',
#   'drsureshukarande'],
#  'TYP': ['ParticipationCertificate']}
