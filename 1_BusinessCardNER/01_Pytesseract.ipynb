# %%
import numpy as np
import pandas as pd
import cv2
import PIL
import pytesseract
import spacy

# %%
img_cv = cv2.imread('../Selected/100.jpeg')

cv2.imshow('Business Card',img_cv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img_cv)
# Out:
# numpy.ndarray

# %%
img_pl = PIL.Image.open('../Selected/100.jpeg')

# %%
type(img_pl)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_pl
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3334x2480>

# %%
text_cv = pytesseract.image_to_string(img_cv)

# %%
print(text_cv)
# Out:
# Certificate no: UC-741395d2-ef66-4591-bf9c-765d4e14459d
#
# U a e my Certificate url: ude.my/UC-74f395d2-ef66-4591-bf9c-765d4e14459d
#
# Reference Number: 0004
#
# CERTIFICATE OF COMPLETION
#
# Informatica PowerCenter -
# Beginner to Expert Level
#
# Instructors Smart Coders Hub
#
# Priyanshu Singh
#
# Date Feb. 1, 2023
# Length 19.5 total hours

# %%
text_pl = pytesseract.image_to_string(img_pl)

# %%
print(text_pl)
# Out:
# Certificate no: UC-741395d2-ef66-4591-bf9c-765d4e14459d
#
# U a ec my Certificate url: ude.my/UC-74f395d2-ef66-4591-bf9c-765d4e14459d
#
# Reference Number: 0004
#
# CERTIFICATE OF COMPLETION
#
# Informatica PowerCenter -
# Beginner to Expert Level
#
# Instructors Smart Coders Hub
#
# Priyanshu Singh
#
# Date Feb. 1, 2023
# Length 19.5 total hours

# %% [markdown]
# ### Image to Data

# %%
data = pytesseract.image_to_data(img_cv)

# %%
print(data)
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	3334	2480	-1
# 2	1	1	0	0	0	2230	221	902	23	-1
# 3	1	1	1	0	0	2230	221	902	23	-1
# 4	1	1	1	1	0	2230	221	902	23	-1
# 5	1	1	1	1	1	2230	221	154	23	96	Certificate
# 5	1	1	1	1	2	2396	227	42	17	93	no:
# 5	1	1	1	1	3	2453	221	679	23	13	UC-741395d2-ef66-4591-bf9c-765d4e14459d
# 2	1	2	0	0	0	200	233	2932	167	-1
# 3	1	2	1	0	0	200	233	2932	167	-1
# 4	1	2	1	1	0	200	233	2932	167	-1
# 5	1	2	1	1	1	200	267	81	94	86	U
# 5	1	2	1	1	2	294	233	96	128	88	a
# 5	1	2	1	1	3	398	265	92	96	85	e
# 5	1	2	1	1	4	500	267	231	133	94	my
# 5	1	2	1	1	5	2105	281	154	23	96	Certificate
# 5	1	2	1	1	6	2271	281	44	23	93	url:
# 5	1	2	1	1	7	2328	281	804	30	16	ude.my/UC-74f395d2-ef66-4591-bf9c-765d4e14459d
# 2	1	3	0	0	0	2753	344	381	23	-1
# 3	1	3	1	0	0	2753	344	381	23	-1
# 4	1	3	1	1	0	2753	344	381	23	-1
# 5	1	3	1	1	1	2753	344	150	23	96	Reference
# 5	1	3	1	1	2	2917	344	125	23	96	Number:
# 5	1	3	1	1	3	3055	344	79	23	96	0004
# 2	1	4	0	0	0	202	646	865	35	-1
# 3	1	4	1	0	0	202	646	865	35	-1
# 4	1	4	1	1	0	202	646	865	35	-1
# 5	1	4	1	1	1	202	646	371	35	95	CERTIFICATE
# 5	1	4	1	1	2	600	646	67	35	95	OF
# 5	1	4	1	1	3	692	646	375	35	95	COMPLETION
# 2	1	5	0	0	0	206	769	2422	423	-1
# 3	1	5	1	0	0	206	769	2422	423	-1
# 4	1	5	1	1	0	206	769	2422	154	-1
# 5	1	5	1	1	1	206	769	1086	154	95	Informatica
# 5	1	5	1	1	2	1336	784	1198	139	93	PowerCenter
# 5	1	5	1	1	3	2580	863	48	16	93	-
# 4	1	5	1	2	0	206	998	2269	194	-1
# 5	1	5	1	2	1	206	998	844	194	96	Beginner
# 5	1	5	1	2	2	1090	1019	183	133	95	to
# 5	1	5	1	2	3	1321	1017	625	173	95	Expert
# 5	1	5	1	2	4	1992	1000	483	152	96	Level
# 2	1	6	0	0	0	204	1265	696	35	-1
# 3	1	6	1	0	0	204	1265	696	35	-1
# 4	1	6	1	1	0	204	1265	696	35	-1
# 5	1	6	1	1	1	204	1265	232	35	95	Instructors
# 5	1	6	1	1	2	473	1265	142	35	96	Smart
# 5	1	6	1	1	3	629	1265	165	35	96	Coders
# 5	1	6	1	1	4	811	1265	89	35	96	Hub
# 2	1	7	0	0	0	210	2003	1019	125	-1
# 3	1	7	1	0	0	210	2003	1019	125	-1
# 4	1	7	1	1	0	210	2003	1019	125	-1
# 5	1	7	1	1	1	210	2005	617	123	92	Priyanshu
# 5	1	7	1	1	2	867	2003	362	125	96	Singh
# 2	1	8	0	0	0	204	2197	546	123	-1
# 3	1	8	1	0	0	204	2197	546	123	-1
# 4	1	8	1	1	0	204	2197	415	43	-1
# 5	1	8	1	1	1	204	2197	100	35	96	Date
# 5	1	8	1	1	2	344	2197	96	35	87	Feb.
# 5	1	8	1	1	3	454	2197	34	43	84	1,
# 5	1	8	1	1	4	504	2197	115	35	84	2023
# 4	1	8	1	2	0	204	2274	546	46	-1
# 5	1	8	1	2	1	204	2274	150	46	96	Length
# 5	1	8	1	2	2	390	2274	93	35	96	19.5
# 5	1	8	1	2	3	496	2274	108	35	96	total
# 5	1	8	1	2	4	623	2274	127	35	96	hours

# %%
data
# Out:
# 'level\tpage_num\tblock_num\tpar_num\tline_num\tword_num\tleft\ttop\twidth\theight\tconf\ttext\n1\t1\t0\t0\t0\t0\t0\t0\t3334\t2480\t-1\t\n2\t1\t1\t0\t0\t0\t2230\t221\t902\t23\t-1\t\n3\t1\t1\t1\t0\t0\t2230\t221\t902\t23\t-1\t\n4\t1\t1\t1\t1\t0\t2230\t221\t902\t23\t-1\t\n5\t1\t1\t1\t1\t1\t2230\t221\t154\t23\t96\tCertificate\n5\t1\t1\t1\t1\t2\t2396\t227\t42\t17\t93\tno:\n5\t1\t1\t1\t1\t3\t2453\t221\t679\t23\t13\tUC-741395d2-ef66-4591-bf9c-765d4e14459d\n2\t1\t2\t0\t0\t0\t200\t233\t2932\t167\t-1\t\n3\t1\t2\t1\t0\t0\t200\t233\t2932\t167\t-1\t\n4\t1\t2\t1\t1\t0\t200\t233\t2932\t167\t-1\t\n5\t1\t2\t1\t1\t1\t200\t
#  '5\t1\t8\t1\t1\t2\t344\t2197\t96\t35\t87\tFeb.',
#  '5\t1\t8\t1\t1\t3\t454\t2197\t34\t43\t84\t1,',
#  '5\t1\t8\t1\t1\t4\t504\t2197\t115\t35\t84\t2023',
#  '4\t1\t8\t1\t2\t0\t204\t2274\t546\t46\t-1\t',
#  '5\t1\t8\t1\t2\t1\t204\t2274\t150\t46\t96\tLength',
#  '5\t1\t8\t1\t2\t2\t390\t2274\t93\t35\t96\t19.5',
#  '5\t1\t8\t1\t2\t3\t496\t2274\t108\t35\t96\ttotal',
#  '5\t1\t8\t1\t2\t4\t623\t2274\t127\t35\t96\thours',
#  '']

# %%
dataList = list(map(lambda x: x.split('\t'),data.split('\n')))
df = pd.DataFrame(dataList[1:],columns=dataList[0])

# %%
df.head(10)
# Out:
#   level page_num block_num par_num line_num word_num  left  top width height  \
# 0     1        1         0       0        0        0     0    0  3334   2480
# 1     2        1         1       0        0        0  2230  221   902     23
# 2     3        1         1       1        0        0  2230  221   902     23
# 3     4        1         1       1        1        0  2230  221   902     23
# 4     5        1         1       1        1        1  2230  221   154     23
# 5     5        1         1       1        1        2  2396  227    42     17
# 6     5        1         1       1        1        3  2453  221   679     23
# 7     2        1         2       0        0        0   200  233  2932    167
# 8     3        1         2       1        0        0   200  233  2932    167
# 9     4        1         2       1        1        0   200  233  2932    167
#
#   conf                                     text
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   96                              Certificate
# 5   93                                      no:
# 6   13  UC-741395d2-ef66-4591-bf9c-765d4e14459d
# 7   -1
# 8   -1
# 9   -1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   level      65 non-null     object
#  1   page_num   64 non-null     object
#  2   block_num  64 non-null     object
#  3   par_num    64 non-null     object
#  4   line_num   64 non-null     object
#  5   word_num   64 non-null     object
#  6   left       64 non-null     object
#  7   top        64 non-null     object
#  8   width      64 non-null     object
#  9   height     64 non-null     object
#  10  conf       64 non-null     object
#  11  text       64 non-null     object
# dtypes: object(12)
# memory usage: 6.2+ KB

# %%
df.dropna(inplace=True) # drop the missing in rows
col_int = ['level','page_num','block_num','par_num','line_num','word_num','left','top','width','height','conf']
df[col_int] = df[col_int].astype(int)

# %%
df.dtypes
# Out:
# level         int32
# page_num      int32
# block_num     int32
# par_num       int32
# line_num      int32
# word_num      int32
# left          int32
# top           int32
# width         int32
# height        int32
# conf          int32
# text         object
# dtype: object

# %%
image = img_cv.copy()
level = 'word'
for l,x,y,w,h,c,txt in df[['level','left','top','width','height','conf','text']].values:
    #print(l,x,y,w,h,c)
    if level == 'page':
        if l == 1:
            cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,0),2)
        else:
            continue
            
    elif level == 'block':
        if l == 2:
            cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
        else:
            continue
    
    elif level == 'para':
        if l == 3:
            cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
        else:
            continue
    
    elif level == 'line':
        if l == 4:
            cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),2)
        else:
            continue
            
    elif level == 'word':
        if l == 5:
            cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
            cv2.putText(image,txt,(x,y),cv2.FONT_HERSHEY_PLAIN,1,(255,0,0),2)
        else:
            continue
            
cv2.imshow("bounding box",image)
cv2.waitKey()
cv2.destroyAllWindows()
